# %% [markdown]
# # AU Mic LCO Data funnel: from many sheets to one dict

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import astropy.constants as c
import astropy.units as u

# %%
gp_kb24 = pd.read_csv('../data/LCO_Photometry/S22_phot/AUMic_gp_kb24_Measurements.csv')
gp_kb26 = pd.read_csv('../data/LCO_Photometry/S22_phot/AUMic_gp_kb26_Measurements.csv')
gp_kb29 = pd.read_csv('../data/LCO_Photometry/S22_phot/AUMic_gp_kb29_Measurements.csv')
gp_kb88 = pd.read_csv('../data/LCO_Photometry/S22_phot/AUMic_gp_kb88_Measurements.csv')
gp_kb87 = pd.read_csv('../data/LCO_Photometry/S22_phot/AUMic_gp_kb87_Measurements.csv')

# gp_kb24 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_gp_kb24_Measurements.csv')
# gp_kb26 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_gp_kb26_Measurements.csv')
# gp_kb29 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_gp_kb29_Measurements.csv')
# gp_kb88 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_gp_kb88_Measurements.csv')

# %%
rp_kb24 = pd.read_csv('../data/LCO_Photometry/S22_phot/AUMic_rp_kb24_Measurements.csv')
rp_kb26 = pd.read_csv('../data/LCO_Photometry/S22_phot/AUMic_rp_kb26_Measurements.csv')
rp_kb29 = pd.read_csv('../data/LCO_Photometry/S22_phot/AUMic_rp_kb29_Measurements.csv')
rp_kb88 = pd.read_csv('../data/LCO_Photometry/S22_phot/AUMic_rp_kb88_Measurements.csv')
rp_kb87 = pd.read_csv('../data/LCO_Photometry/S22_phot/AUMic_rp_kb87_Measurements.csv')

# rp_kb24 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_rp_kb24_Measurements.csv')
# rp_kb26 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_rp_kb26_Measurements.csv')
# rp_kb29 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_rp_kb29_Measurements.csv')
# rp_kb88 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_rp_kb88_Measurements.csv')

# %%
# ip_kb24 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_ip_kb24_Measurements.csv')
# ip_kb26 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_ip_kb26_Measurements.csv')
# ip_kb29 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_ip_kb29_Measurements.csv')
# ip_kb88 = pd.read_csv('../data/LCO_Photometry/F21_phot/AUMic_ip_kb88_Measurements.csv')

# %%
AU_Mictionary = {
    
    "gp" : {
        
        "kb24" : {
            "time [BJD]" : gp_kb24['BJD_TDB'],
            "flux" : gp_kb24['rel_flux_T1'],
            "flux_err" : gp_kb24['rel_flux_err_T1'],
            "airmass" : gp_kb24['AIRMASS'],
            "peak" : gp_kb24['Peak_T1'],
            "SNR" : (gp_kb24['rel_flux_T1']/gp_kb24['rel_flux_err_T1']),
            "exptime" : gp_kb24['EXPTIME'],
        },
        
        "kb26" : {
            "time [BJD]" : gp_kb26['BJD_TDB'],
            "flux" : gp_kb26['rel_flux_T1'],
            "flux_err" : gp_kb26['rel_flux_err_T1'],
            "airmass" : gp_kb26['AIRMASS'],
            "peak" : gp_kb26['Peak_T1'],
            "SNR" : (gp_kb26['rel_flux_T1']/gp_kb26['rel_flux_err_T1']),
            "exptime" : gp_kb26['EXPTIME'],
        },
        
        "kb29" : {
            "time [BJD]" : gp_kb29['BJD_TDB'],
            "flux" : gp_kb29['rel_flux_T1'],
            "flux_err" : gp_kb29['rel_flux_err_T1'],
            "airmass" : gp_kb29['AIRMASS'],
            "peak" : gp_kb29['Peak_T1'],
            "SNR" : (gp_kb29['rel_flux_T1']/gp_kb29['rel_flux_err_T1']),    
            "exptime" : gp_kb29['EXPTIME'],
        },
        
        "kb87" : {
            "time [BJD]" : gp_kb87['BJD_TDB'],
            "flux" : gp_kb87['rel_flux_T1'],
            "flux_err" : gp_kb87['rel_flux_err_T1'],
            "airmass" : gp_kb87['AIRMASS'],
            "peak" : gp_kb87['Peak_T1'],
            "SNR" : (gp_kb87['rel_flux_T1']/gp_kb87['rel_flux_err_T1']),
            "exptime" : gp_kb87['EXPTIME'],
        },
        
        "kb88" : {
            "time [BJD]" : gp_kb88['BJD_TDB'],
            "flux" : gp_kb88['rel_flux_T1'],
            "flux_err" : gp_kb88['rel_flux_err_T1'],
            "airmass" : gp_kb88['AIRMASS'],
            "peak" : gp_kb88['Peak_T1'],
            "SNR" : (gp_kb88['rel_flux_T1']/gp_kb88['rel_flux_err_T1']),
            "exptime" : gp_kb88['EXPTIME'],
        }        
      
    },
    
    "rp" : {
        
        "kb24" : {
            "time [BJD]" : rp_kb24['BJD_TDB'],
            "flux" : rp_kb24['rel_flux_T1'],
            "flux_err" : rp_kb24['rel_flux_err_T1'],
            "airmass" : rp_kb24['AIRMASS'],
            "peak" : rp_kb24['Peak_T1'],
            "SNR" : (rp_kb24['rel_flux_T1']/rp_kb24['rel_flux_err_T1']),
            "exptime" : rp_kb24['EXPTIME'],
        },
        
        "kb26" : {
            "time [BJD]" : rp_kb26['BJD_TDB'],
            "flux" : rp_kb26['rel_flux_T1'],
            "flux_err" : rp_kb26['rel_flux_err_T1'],
            "airmass" : rp_kb26['AIRMASS'],
            "peak" : rp_kb26['Peak_T1'],
            "SNR" : (rp_kb26['rel_flux_T1']/rp_kb26['rel_flux_err_T1']),
            "exptime" : rp_kb26['EXPTIME'],
        },
        
        "kb29" : {
            "time [BJD]" : rp_kb29['BJD_TDB'],
            "flux" : rp_kb29['rel_flux_T1'],
            "flux_err" : rp_kb29['rel_flux_err_T1'],
            "airmass" : rp_kb29['AIRMASS'],
             "peak" : rp_kb29['Peak_T1'],
            "SNR" : (rp_kb29['rel_flux_T1']/rp_kb29['rel_flux_err_T1']),
            "exptime" : rp_kb29['EXPTIME'],
        },
        
        "kb87" : {
            "time [BJD]" : rp_kb87['BJD_TDB'],
            "flux" : rp_kb87['rel_flux_T1'],
            "flux_err" : rp_kb87['rel_flux_err_T1'],
            "airmass" : rp_kb87['AIRMASS'],
             "peak" : rp_kb87['Peak_T1'],
            "SNR" : (rp_kb87['rel_flux_T1']/rp_kb87['rel_flux_err_T1']),
            "exptime" : rp_kb87['EXPTIME'],
        },
        
        "kb88" : {
            "time [BJD]" : rp_kb88['BJD_TDB'],
            "flux" : rp_kb88['rel_flux_T1'],
            "flux_err" : rp_kb88['rel_flux_err_T1'],
            "airmass" : rp_kb88['AIRMASS'],
             "peak" : rp_kb88['Peak_T1'],
            "SNR" : (rp_kb88['rel_flux_T1']/rp_kb88['rel_flux_err_T1']),
            "exptime" : rp_kb88['EXPTIME'],
        }
      
    },
    
#     "ip" : {
        
#         "kb24" : {
#             "time [BJD]" : ip_kb24['BJD_TDB'],
#             "flux" : ip_kb24['rel_flux_T1'],
#             "flux_err" : ip_kb24['rel_flux_err_T1'],
#             "airmass" : ip_kb24['AIRMASS'],
#             "peak" : ip_kb24['Peak_T1'],
#             "SNR" : (ip_kb24['rel_flux_T1']/ip_kb24['rel_flux_err_T1']),
#             "exptime" : ip_kb24['EXPTIME'],
#         },
        
#         "kb26" : {
#             "time [BJD]" : ip_kb26['BJD_TDB'],
#             "flux" : ip_kb26['rel_flux_T1'],
#             "flux_err" : ip_kb26['rel_flux_err_T1'],
#             "airmass" : ip_kb26['AIRMASS'],
#             "peak" : ip_kb26['Peak_T1'],
#             "SNR" : (ip_kb26['rel_flux_T1']/ip_kb26['rel_flux_err_T1']),
#             "exptime" : ip_kb26['EXPTIME'],
#         },
        
#         "kb29" : {
#             "time [BJD]" : ip_kb29['BJD_TDB'],
#             "flux" : ip_kb29['rel_flux_T1'],
#             "flux_err" : ip_kb29['rel_flux_err_T1'],
#             "airmass" : ip_kb29['AIRMASS'],
#             "peak" : ip_kb29['Peak_T1'],
#             "SNR" : (ip_kb29['rel_flux_T1']/ip_kb29['rel_flux_err_T1']),
#             "exptime" : ip_kb29['EXPTIME'],
#         },
        
#         "kb88" : {
#             "time [BJD]" : ip_kb88['BJD_TDB'],
#             "flux" : ip_kb88['rel_flux_T1'],
#             "flux_err" : ip_kb88['rel_flux_err_T1'],
#             "airmass" : ip_kb88['AIRMASS'],
#             "peak" : ip_kb88['Peak_T1'],
#             "SNR" : (ip_kb88['rel_flux_T1']/ip_kb88['rel_flux_err_T1']),
#             "exptime" : ip_kb88['EXPTIME'],
#         }
      
#     },
    
    
}

# %%
# load pickle module
import pickle

# create a binary pickle file 
# f = open("../data/LCO_Photometry/F21_phot/AU_Mickle.pkl","wb")
f = open("../data/LCO_Photometry/S22_phot/AU_Mickle.pkl","wb")

# write the python object (dict) to pickle file
pickle.dump(AU_Mictionary,f)

# close file
f.close()

# %%
# df = pd.DataFrame(data=AU_Mictionary)

# %%
# plt.figure(figsize=(8,3))
# plt.scatter(df.gp.kb24['exptime'], df.gp.kb24['SNR'], label='kb24',alpha=0.2)
# plt.scatter(df.gp.kb26['exptime'], df.gp.kb26['SNR'], label='kb26',alpha=0.2)
# plt.scatter(df.gp.kb29['exptime'], df.gp.kb29['SNR'], label='kb29',alpha=0.2)
# plt.scatter(df.gp.kb87['exptime'], df.gp.kb87['SNR'], label='kb87',alpha=0.2)
# plt.scatter(df.gp.kb88['exptime'], df.gp.kb88['SNR'], label='kb88',alpha=0.2)
# #plt.xlim((59455.48 + 2400000.5 + 5),(59455.48 + 2400000.5 - 5))
# #plt.ylim(0,12)
# #plt.axvline((59455.48 + 2400000.5),label='T0')
# plt.xlabel('exptime')
# plt.ylabel('SNR')
# plt.title('AU Mic gp Peak Counts')
# plt.legend()
# plt.savefig('figs/gp_peak_counts.pdf')
# plt.show()

# %%
# plt.figure(figsize=(8,3))
# plt.scatter(df.rp.kb24['exptime'], df.rp.kb24['SNR'], label='kb24',alpha=0.2)
# plt.scatter(df.rp.kb26['exptime'], df.rp.kb26['SNR'], label='kb26',alpha=0.2)
# plt.scatter(df.rp.kb29['exptime'], df.rp.kb29['SNR'], label='kb29',alpha=0.2)
# plt.scatter(df.rp.kb87['exptime'], df.rp.kb87['SNR'], label='kb87',alpha=0.2)
# plt.scatter(df.rp.kb88['exptime'], df.rp.kb88['SNR'], label='kb88',alpha=0.2)
# #plt.xlim((59455.48 + 2400000.5 + 5),(59455.48 + 2400000.5 - 5))
# #plt.ylim(0,12)
# #plt.axvline((59455.48 + 2400000.5),label='T0')
# plt.xlabel('exptime')
# plt.ylabel('SNR')
# plt.title('AU Mic rp Peak Counts')
# plt.legend()
# plt.savefig('figs/rp_peak_counts.pdf')
# plt.show()
