# %% [markdown]
# ## Zach's Updated Model Spectra!

# %%
from chromatic import get_phoenix_photons, get_planck_photons, version
import matplotlib.pyplot as plt, numpy as np
import astropy.units as u, astropy.constants as con

# %%
# retrieve a wavelength array and a flux array
wavelength, surface_flux = get_phoenix_photons(
    temperature=5780, logg=4.43, metallicity=0.0, R=1000
)

# plot the wavelength array
plt.figure(figsize=(8, 3), dpi=300)
plt.plot(wavelength, surface_flux, label="PHOENIX model")

# for comparison, plot a Planck spectrum
w_planck, f_planck = get_planck_photons(temperature=5780)
plt.plot(w_planck, f_planck, label="Planck function")

# add some labels
plt.xlabel(f"Wavelength ({wavelength.unit.to_string('latex_inline')})")
plt.ylabel(f"Surface Flux ({surface_flux.unit.to_string('latex_inline')})")
plt.legend(frameon=False);
# Out:
#             Downloading pre-processed grid for R=1000, metallicity=0.0 from
#             https://casa.colorado.edu/~bertathompson/chromatic/phoenix_photons_metallicity=0.0_R=1000.npy
#             Because the resolution is R<=1000, this should be pretty quick.
# 🌈 Warning:
# The progress bar for this download is not being shown
# because `astropy.utils.data.download_file` is being run
# from a jupyter notebook instead of from the terminal.

# %%
plt.figure(figsize=(8, 3), dpi=300)
for R in [10000, 1000, 100, 10]:
    w, f = get_phoenix_photons(R=R)
    plt.plot(w, f, alpha=0.5, label=f"R={R}")
plt.xlabel(f"Wavelength ({wavelength.unit.to_string('latex_inline')})")
plt.ylabel(f"Surface Flux ({surface_flux.unit.to_string('latex_inline')})")
plt.legend(frameon=False);
# Out:
#             Downloading pre-processed grid for R=10000, metallicity=0.0 from
#             https://casa.colorado.edu/~bertathompson/chromatic/phoenix_photons_metallicity=0.0_R=10000.npy
#             Because the resolution is R>1000, this might be annoyingly slow.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/Desktop/PhD_Thesis/chromatic/chromatic/spectra/phoenix.py in get_average_spectrum(self, temperature, logg, metallicity, R, wavelength, wavelength_edges, visualize)
#     764             if (wavelength is None) and (wavelength_edges is None):
# --> 765                 assert self.metadata["R"] == R
#     766             # if wavelength grids are provided, make sure the grid has high enough R
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# <ipython-input-3-fbbac3995119> in <module>
#       1 plt.figure(figsize=(8, 3), dpi=300)
#       2 for R in [10000, 1000, 100, 10]:
# ----> 3     w, f = get_phoenix_photons(R=R)
#       4     plt.plot(w, f, alpha=0.5, label=f"R={R}")
#       5 plt.xlabel(f"Wavelength ({wavelength.unit.to_string('latex_inline')})")
#
# ~/Desktop/PhD_Thesis/chromatic/chromatic/spectra/phoenix.py in get_average_spectrum(self, temperature, logg, metallicity, R, wavelength, wavelength_edges, visualize)
#     784         except (AttributeError, AssertionError):
#     785             if metallicity in self._available_metallicities:
# --> 786                 self._load_grid(
#     787                     self._find_smallest_R(R=R),
#     788                     metallicity=metallicity,
#
# ~/Desktop/PhD_Thesis/chromatic/chromatic/spectra/phoenix.py in _load_grid(self, R, metallicity)
#     553
#     554         metadata, models = np.load(
# --> 555             self._get_local_grid(R, metallicity=metallicity), allow_pickle=True
#     556         )[()]
#     557
#
# ~/Desktop/PhD_Thesis/chromatic/chromatic/spectra/phoenix.py in _get_local_grid(self, R, metallicity, directory)
#     532             return bespoke
#     533         else:
# --> 534             return self._download_grid(R, metallicity=metallicity)
#     535
#     536     def _load_grid(self, R, metallicity=0.0):
#
# ~/Desktop/PhD_Thesis/chromatic/chromatic/spectra/phoenix.py in _download_grid(self, R, metallicity, cache)
#     122             )
#     123
# --> 124             self._local_paths[R] = download_file_with_warning(
#     125                 url, pkgname=self._cache_label, cache=cache, show_progress=True
#     126             )
#
# ~/Desktop/PhD_Thesis/chromatic/chromatic/imports.py in download_file_with_warning(*args, **kwargs)
#      78         )
#      79     kwargs["show_progress"] = True
# ---> 80     return download_file(*args, **kwargs)
#      81
#      82
#
# /opt/anaconda3/envs/ers-transit/lib/python3.9/site-packages/astropy/utils/data.py in download_file(remote_url, cache, show_progress, timeout, sources, pkgname, http_headers, ssl_context, allow_insecure)
#    1361     for source_url in sources:
#    1362         try:
# -> 1363             f_name = _download_file_from_source(
#    1364                     source_url,
#    1365                     timeout=timeout,
#
# /opt/anaconda3/envs/ers-transit/lib/python3.9/site-packages/astropy/utils/data.py in _download_file_from_source(source_url, show_progress, timeout, remote_url, cache, pkgname, http_headers, ftp_tls, ssl_context, allow_insecure)
#    1199                         bytes_read += len(block)
#    1200                         p.update(bytes_read)
# -> 1201                         block = remote.read(conf.download_block_size)
#    1202                         if size is not None and bytes_read > size:
#    1203                             raise urllib.error.URLError(
#
# /opt/anaconda3/envs/ers-transit/lib/python3.9/http/client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# /opt/anaconda3/envs/ers-transit/lib/python3.9/http/client.py in readinto(self, b)
#     501         # connection, and the user is reading more bytes than will be provided
#     502         # (for example, reading in 1k chunks)
# --> 503         n = self.fp.readinto(b)
#     504         if not n and b:
#     505             # Ideally, we would raise IncompleteRead if the content-length
#
# /opt/anaconda3/envs/ers-transit/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# /opt/anaconda3/envs/ers-transit/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /opt/anaconda3/envs/ers-transit/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# timeout: The read operation timed out

# %%
plt.figure(figsize=(8, 3), dpi=300)
w, f = get_phoenix_photons(wavelength=np.linspace(0.4, 0.7, 1000) * u.micron)
plt.plot(w, f)
plt.xlabel(f"Wavelength ({wavelength.unit.to_string('latex_inline')})")
plt.ylabel(f"Surface Flux ({surface_flux.unit.to_string('latex_inline')})");
